# %%
import pandas as pd
import numpy as np

# %%
df_xml = pd.read_xml("data/atributos_xml.xml")
df_xml
# Out:
#        level_0  index  time    age gender
# 0            0      0   910  50-54    Man
# 1            1      1   784  50-54    Man
# 2            2      2   924  22-24    Man
# 3            3      3   575  45-49    Man
# 4            4      4   781  45-49    Man
# ...        ...    ...   ...    ...    ...
# 25968    25968  25968  1756  30-34    Man
# 25969    25969  25969   253  22-24    Man
# 25970    25970  25970   494  50-54    Man
# 25971    25971  25971   277  45-49    Man
# 25972    25972  25972   255  18-21    Man
#
# [25973 rows x 5 columns]

# %%
# archivo limpio como lo queremos
df_xml_final = df_xml.drop(["level_0", "index", "time"], axis = 1, inplace=False)

# %%
df_q10 = pd.read_csv("data/q10.csv", index_col=0)
df_q10
# Out:
#               Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# index
# 0                    NaN  Colab Notebooks        NaN        NaN        NaN
# 1       Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2       Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3                    NaN  Colab Notebooks        NaN        NaN        NaN
# 4                    NaN              NaN        NaN        NaN        NaN
# ...                  ...              ...        ...        ...        ...
# 25968                NaN  Colab Notebooks        NaN        NaN        NaN
# 25969                NaN              NaN        NaN        NaN        NaN
# 25970                NaN              NaN        NaN        NaN        NaN
# 25971                NaN              NaN        NaN        NaN        NaN
# 25972                NaN              NaN        NaN        NaN        NaN
#
# ...

# %% [markdown]
# # Remanente

# %%
df_remanentes = pd.read_csv("data/remanentes_encuesta.csv", index_col=0)
df_remanentes.head(1)
# Out:
#    index                                         Q18_Part_1 Q18_Part_2  \
# 0      0  General purpose image/video tools (PIL, cv2, s...        NaN
#
#   Q18_Part_3 Q18_Part_4 Q18_Part_5 Q18_Part_6 Q18_OTHER  \
# 0        NaN        NaN        NaN        NaN       NaN
#
#                                           Q19_Part_1 Q19_Part_2  ...  \
# 0  Word embeddings/vectors (GLoVe, fastText, word...        NaN  ...
#
#   Q38_B_Part_3 Q38_B_Part_4 Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#   Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 0          NaN          NaN           NaN           NaN         NaN
#
# [1 rows x 213 columns]

# %%
df_q27= df_remanentes.filter(items=["Q27_A_Part_1","Q27_A_Part_2",	"Q27_A_Part_3",	"Q27_A_Part_4",	"Q27_A_Part_5", "Q27_A_Part_6",	"Q27_A_Part_7",	"Q27_A_Part_8",	"Q27_A_Part_9",	"Q27_A_Part_10","Q27_A_Part_11","Q27_A_OTHER"])

# %%
df_q29 = df_remanentes.filter(items=["Q29_A_Part_1","Q29_A_Part_2",	"Q29_A_Part_3",	"Q29_A_Part_4","Q29_A_OTHER"])

# %%
df_40= df_remanentes.filter(items=["Q40_Part_1","Q40_Part_2","Q40_Part_3","Q40_Part_4","Q40_Part_5","Q40_Part_6","Q40_Part_7","Q40_Part_8","Q40_Part_9","Q40_Part_10","Q40_Part_11","Q40_OTHER"])

# %%
df_42 = df_remanentes.filter(items=["Q42_Part_1","Q42_Part_2","Q42_Part_3","Q42_Part_4",	"Q42_Part_5","Q42_Part_6","Q42_Part_7",	"Q42_Part_8","Q42_Part_9",	"Q42_Part_10",	"Q42_Part_11",	"Q42_OTHER"])

# %%
pd.options.display.max_columns = None

# %% [markdown]
# ## Funcion

# %%
def sumar_columnas (*args):
     
     set_tupla = list(set(args))
     set_tupla.remove(np.nan)
     
     
     if len(set_tupla) == 0:
          return np.nan
     elif len(set_tupla) > 1:
          return ", ".join(set_tupla)

     else:
          return set_tupla[0]

# %%
df_q27_columna= df_q27.apply(lambda locura: sumar_columnas(locura["Q27_A_Part_1"], locura["Q27_A_Part_2"], locura['Q27_A_Part_3'], locura['Q27_A_Part_4'],locura['Q27_A_Part_5'],locura['Q27_A_Part_6'],locura['Q27_A_Part_7'],locura['Q27_A_Part_8'],locura['Q27_A_Part_9'],locura['Q27_A_Part_10'],locura['Q27_A_Part_11'],locura['Q27_A_OTHER']), axis = 1)
# este df tiene completa la pregunta q27. Va para el archivo final

# %%
df_q29_columna= df_q29.apply(lambda locura: sumar_columnas(locura['Q29_A_Part_1'],locura['Q29_A_Part_2'],locura['Q29_A_Part_3'],locura['Q29_A_Part_4'],locura['Q29_A_OTHER']), axis = 1)
#esta columna va para archivo final

# %%
df_q29.head()
# Out:
#   Q29_A_Part_1                        Q29_A_Part_2  \
# 0          NaN                                 NaN
# 1          NaN                                 NaN
# 2          NaN                                 NaN
# 3          NaN                                 NaN
# 4          NaN   Microsoft Azure Virtual Machines
#
#                     Q29_A_Part_3 Q29_A_Part_4 Q29_A_OTHER
# 0   Google Cloud Compute Engine           NaN         NaN
# 1                            NaN          NaN         NaN
# 2                            NaN          NaN         NaN
# 3                            NaN          NaN         NaN
# 4                            NaN          NaN         NaN

# %%
df_q40_columna = df_40.apply(lambda locura: sumar_columnas(locura['Q40_Part_1'],locura['Q40_Part_2'],locura['Q40_Part_3'],locura['Q40_Part_4'],locura['Q40_Part_5'], locura['Q40_Part_6'],locura['Q40_Part_7'],locura['Q40_Part_8'],locura['Q40_Part_9'],locura['Q40_Part_10'],locura['Q40_Part_11'],locura['Q40_OTHER'] ), axis = 1)
#archivo para final

# %%
df_q42_columna = df_42.apply(lambda locura: sumar_columnas(locura['Q42_Part_1'],locura['Q42_Part_2'],locura['Q42_Part_3'],locura['Q42_Part_4'],locura['Q42_Part_5'], locura['Q42_Part_6'],locura['Q42_Part_7'],locura['Q42_Part_8'],locura['Q42_Part_9'],locura['Q42_Part_10'],locura['Q42_Part_11'],locura['Q42_OTHER'] ), axis = 1)
#para archivo final

# %% [markdown]
# # TXT

# %%
with open("data/txt.txt") as f:
    txt = f.readlines()

# %%
df_txt = pd.read_csv("data/txt.txt", sep=";")

# %%
df_txt_final = df_txt.filter(items=["Q3", "Q4", "Q5", "Q7", "Q8", "Q9", "Q11", "Q14", "Q20", "Q21", "Q22", "Q24", "Q25", "Q32", "Q33", "Q41"])

# %%
df_txt_final.head(2)
# Out:
#           Q3                 Q4                       Q5                  Q7  \
# 0      India  Bachelor’s degree                    Other           Python, R
# 1  Indonesia    Master’s degree  Program/Project Manager   SQL, C, C++, Java
#
#        Q8                           Q9  \
# 0  Python                  Vim / Emacs
# 1  Python   Notepad++,Jupyter Notebook
#
#                                                  Q11  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                                                  Q14  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
#
#                          Q20                   Q21  Q22  \
# 0  Manufacturing/Fabrication      50-249 employees  3-4
# 1  Manufacturing/Fabrication  1000-9,999 employees  1-2
#
#                                                  Q24            Q25  \
# ...

# %% [markdown]
# - Subconjunto de archivos con los datos seleccionados para unificar
#
# df_xml - con datos edad y género
#
# df_q10 - con datos de la 10
#
# df_q27 - con datos de la 27
#
# df_q29 - con datos de la 29
#
# df_q40 - con datos de la 40
#
# df_q42 - con datos de la 42
#
# df_txt_filtrado - datos del txt

# %% [markdown]
# # Q10

# %%
df_q10['q_10_completa']= df_q10.apply(lambda locura: sumar_columnas(locura["Q10_Part_1"], locura["Q10_Part_2"], locura['Q10_Part_3'], locura['Q10_Part_4'],locura['Q10_Part_5'],locura['Q10_Part_6'],locura['Q10_Part_7'],locura['Q10_Part_8'],locura['Q10_Part_9'],locura['Q10_Part_10'],locura['Q10_Part_11'],locura['Q10_Part_12'],locura['Q10_Part_13'],locura['Q10_Part_14'],locura['Q10_Part_15'],locura['Q10_Part_16'],locura['Q10_OTHER']), axis = 1)

# %%
df_q10['q_10_completa']
# Out:
# index
# 0                                          Colab Notebooks
# 1                       Colab Notebooks,  Kaggle Notebooks
# 2                                         Kaggle Notebooks
# 3                                          Colab Notebooks
# 4                                     Google Cloud Datalab
#                                ...
# 25968     Databricks Collaborative Notebooks , Colab No...
# 25969                                                 None
# 25970                                                  NaN
# 25971                                                 None
# 25972                                                  NaN
# Name: q_10_completa, Length: 25973, dtype: object

# %%
df_q10.drop(["Q10_Part_1"], inplace=True, axis=1)

# %%
df_q10.drop(['Q10_Part_3','Q10_Part_2','Q10_Part_4','Q10_Part_5','Q10_Part_6','Q10_Part_7','Q10_Part_8'], inplace=True, axis= 1)

# %%
df_q10.drop(['Q10_Part_9','Q10_Part_10','Q10_Part_11','Q10_Part_12','Q10_Part_13','Q10_Part_14','Q10_Part_15'], inplace=True, axis= 1)

# %%
df_q10.drop(['Q10_Part_16', 'Q10_OTHER'], inplace=True, axis=1)

# %%
df_q10 #va para archivo final
# Out:
#                                            q_10_completa
# index
# 0                                        Colab Notebooks
# 1                     Colab Notebooks,  Kaggle Notebooks
# 2                                       Kaggle Notebooks
# 3                                        Colab Notebooks
# 4                                   Google Cloud Datalab
# ...                                                  ...
# 25968   Databricks Collaborative Notebooks , Colab No...
# 25969                                               None
# 25970                                                NaN
# 25971                                               None
# 25972                                                NaN
#
# [25973 rows x 1 columns]

# %%
df_q10.to_csv('data/df_q10')

# %%
df_q10.dtypes
# Out:
# q_10_completa    object
# dtype: object

# %%
print(df_q27_columna)
print('-----')
print(df_q29_columna.head(2))
print('-----')
print(df_q40_columna.head(2))
print('-----')
print(df_q42_columna.head(2))
# Out:
# 0                          Google Cloud Platform (GCP)
# 1                                                   NaN
# 2                                                  None
# 3                                                   NaN
# 4                                      Microsoft Azure
#                               ...
# 25968     Amazon Web Services (AWS) ,  Microsoft Azure
# 25969                                               NaN
# 25970                                               NaN
# 25971                                               NaN
# 25972                                               NaN
# Length: 25973, dtype: object
# -----
# 0     Google Cloud Compute Engine
# 1                              NaN
# dtype: object
# -----
# 0    Udacity, Coursera, edX, DataCamp, Udemy, Kaggl...
# 1    Kaggle Learn Courses, Cloud-certification prog...
# dtype: object
# -----
# 0    Kaggle (notebooks, forums, etc), Blogs (Toward...
# ...

# %%
q27_final = pd.DataFrame(df_q27_columna)
q27_final.head(2)
# Out:
#                                0
# 0   Google Cloud Platform (GCP)
# 1                            NaN

# %%
q29_final = pd.DataFrame(df_q29_columna)
q29_final.head(2)
# Out:
#                                0
# 0   Google Cloud Compute Engine
# 1                            NaN

# %%
q40_final = pd.DataFrame(df_q40_columna)
q40_final.head(2)
# Out:
#                                                    0
# 0  Udacity, Coursera, edX, DataCamp, Udemy, Kaggl...
# 1  Kaggle Learn Courses, Cloud-certification prog...

# %%
q42_final = pd.DataFrame(df_q42_columna)
q42_final.head(2)
# Out:
#                                                    0
# 0  Kaggle (notebooks, forums, etc), Blogs (Toward...
# 1  Journal Publications (peer-reviewed journals, ...

# %%
df_xml_final.head(2)
# Out:
#      age gender
# 0  50-54    Man
# 1  50-54    Man

# %%
q27_final.rename({0:'q_27_completa'}, axis = 1, inplace = True)
q29_final.rename({0:'q_29_completa'}, axis = 1, inplace = True)
q40_final.rename({0:'q_40_completa'}, axis = 1, inplace = True)
q42_final.rename({0:'q_42_completa'}, axis = 1, inplace = True)

# %% [markdown]
# ## Merge

# %%
encuesta_limpia = pd.concat([df_xml_final,df_txt_final, df_q10, q27_final, q29_final, q40_final, q42_final], axis = 1, join= 'outer')

# %%
encuesta_limpia.head(4)
# Out:
#      age gender         Q3                 Q4                       Q5  \
# 0  50-54    Man      India  Bachelor’s degree                    Other
# 1  50-54    Man  Indonesia    Master’s degree  Program/Project Manager
# 2  22-24    Man   Pakistan    Master’s degree        Software Engineer
# 3  45-49    Man     Mexico    Doctoral degree       Research Scientist
#
#                    Q7      Q8                                Q9  \
# 0           Python, R  Python                       Vim / Emacs
# 1   SQL, C, C++, Java  Python        Notepad++,Jupyter Notebook
# 2   Python, C++, Java  Python  PyCharm ,Jupyter Notebook, Other
# 3              Python  Python           Spyder,Jupyter Notebook
#
#                                                  Q11  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
# 2                                           A laptop
# 3  A cloud computing platform (AWS, Azure, GCP, h...
#
# ...

# %%
# encuesta_limpia = df_xml_final.merge(['df_txt_final', 'df_q10', 'q27_final', 'q29_final', 'q40_final', 'q42_final'], how= 'outer', )

# comentado por si acaso
