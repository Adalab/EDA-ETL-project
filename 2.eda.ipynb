# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sidetable

# %%
plt.rcParams["figure.figsize"] = (10,5)
pd.options.display.max_columns = None

# %% [markdown]
# ## Exploración general

# %%
df = pd.read_csv('data/encuesta_limpia.csv', index_col= 0)
df.sample()
# Out:
#         edad genero   pais  \
# 23728  18-21  Woman  Other
#
#                                                                formacion  \
# 23728  Some college/university study without earning a bachelor’s degree
#
#             ocupacion  \
# 23728  Data Scientist
#
#                                                                   actividades  \
# 23728  Analyze and understand data to influence product or business decisions
#
#                     sector  tamaño_empresa equipo salario  \
# 23728  Academics/Education  0-49 employees      0  $0-999
#
#       lenguajes_programacion lenguajes_recomendados       IDE  \
# 23728              Python, C                      C  PyCharm
#
#       plataforma_computacion visualizacion productos_big_data  \
# 23728               A laptop          None                NaN
#
#                                               herramienta_data_analytics  \
# 23728  Basic statistical software (Microsoft Excel, Google Sheets, etc.)
#
#       notebooks               plataformas_nube uso_plataformas
# 23728      None   Google Cloud Platform (GCP)        No / None

# %%
print(f"El dataframe tiene {df.shape[0]} filas y {df.shape[1]} columnas")
# Out:
# El dataframe tiene 25973 filas y 20 columnas

# %%
df.stb.missing()
# Out:
#                             missing  total    percent
# productos_big_data            21317  25973  82.073692
# uso_plataformas               19739  25973  75.998152
# plataformas_nube              16252  25973  62.572672
# salario                       10582  25973  40.742309
# actividades                   10338  25973  39.802872
# equipo                         9847  25973  37.912448
# tamaño_empresa                 9722  25973  37.431179
# sector                         9648  25973  37.146267
# herramienta_data_analytics     7484  25973  28.814538
# visualizacion                  2003  25973   7.711855
# plataforma_computacion         1253  25973   4.824241
# notebooks                      1163  25973   4.477727
# IDE                            1039  25973   4.000308
# lenguajes_recomendados         1033  25973   3.977207
# lenguajes_programacion         1032  25973   3.973357
# genero                            0  25973   0.000000
# ocupacion                         0  25973   0.000000
# formacion                         0  25973   0.000000
# pais                              0  25973   0.000000
# edad                              0  25973   0.000000

# %%
df.describe(include='all').T
# Out:
#                             count unique  \
# edad                        25973     11
# genero                      25973      5
# pais                        25973     66
# formacion                   25973      7
# ocupacion                   25973     15
# actividades                 15635     96
# sector                      16325     18
# tamaño_empresa              16251      5
# equipo                      16126      7
# salario                     15391     26
# lenguajes_programacion      24941    825
# lenguajes_recomendados      24940     13
# IDE                         24934   1330
# plataforma_computacion      24720      6
# visualizacion               23970    467
# productos_big_data           4656     20
# herramienta_data_analytics  18489      6
# notebooks                   24810    723
# plataformas_nube             9721    280
# uso_plataformas              6234     16
#
#                                                                                                top  \
# edad                                                                                         25-29
# genero                                                                                         Man
# pais                                                                                         India
# formacion                                                                          Master’s degree
# ocupacion                                                                                  Student
# actividades                 Analyze and understand data to influence product or business decisions
# sector                                                                        Computers/Technology
# tamaño_empresa                                                                      0-49 employees
# equipo                                                                                         1-2
# salario                                                                                     $0-999
# lenguajes_programacion                                                                      Python
# lenguajes_recomendados                                                                      Python
# IDE                                                                               Jupyter Notebook
# plataforma_computacion                                                                    A laptop
# visualizacion                                                                 Matplotlib ,Seaborn
# productos_big_data                                                                          MySQL
# herramienta_data_analytics       Basic statistical software (Microsoft Excel, Google Sheets, etc.)
# notebooks                                                                                     None
# plataformas_nube                                                                              None
# uso_plataformas                                                                          No / None
#
#                              freq
# edad                         4931
# genero                      20598
# pais                         7434
# formacion                   10132
# ocupacion                    6804
# actividades                  2891
# sector                       4079
# tamaño_empresa               5055
# equipo                       3642
# salario                      3369
# lenguajes_programacion       4740
# lenguajes_recomendados      20213
# IDE                          2341
# plataforma_computacion      16231
# visualizacion                5697
# productos_big_data           1110
# herramienta_data_analytics   7246
# notebooks                    7174
# plataformas_nube             2689
# uso_plataformas              1795

# %% [markdown]
# ## Exploración por edad

# %%
df['edad'].value_counts().reset_index()
# Out:
#     index  edad
# 0   25-29  4931
# 1   18-21  4901
# 2   22-24  4694
# 3   30-34  3441
# 4   35-39  2504
# 5   40-44  1890
# 6   45-49  1375
# 7   50-54   964
# 8   55-59   592
# 9   60-69   553
# 10    70+   128

# %% [markdown]
# ## Exploración por género

# %%
df['genero'].value_counts().reset_index()
# Out:
#                      index  genero
# 0                      Man   20598
# 1                    Woman    4890
# 2        Prefer not to say     355
# 3                Nonbinary      88
# 4  Prefer to self-describe      42

# %% [markdown]
# ## Exploración por país

# %%
df['pais'].value_counts().reset_index()
# Out:
#                                                    index  pais
# 0                                                  India  7434
# 1                               United States of America  2650
# 2                                                  Other  1270
# 3                                                  Japan   921
# 4                                                  China   814
# 5                                                 Brazil   751
# 6                                                 Russia   742
# 7                                                Nigeria   702
# 8   United Kingdom of Great Britain and Northern Ireland   550
# 9                                               Pakistan   530
# 10                                                 Egypt   482
# 11                                               Germany   470
# 12                                                 Spain   454
# 13                                             Indonesia   444
# 14                                                Turkey   416
# 15                                                France   401
# 16                                           South Korea   359
# 17                                                Taiwan   334
# 18                                                Canada   331
# 19                                            Bangladesh   317
# 20                                                 Italy   311
# 21                                                Mexico   279
# 22                                              Viet Nam   277
# 23                                             Australia   264
# 24                                                 Kenya   248
# 25                                              Colombia   225
# 26                                                Poland   219
# 27                          Iran, Islamic Republic of...   195
# 28                                               Ukraine   186
# 29                                             Singapore   182
# 30                                             Argentina   182
# 31                                              Malaysia   156
# 32                                           Netherlands   153
# 33                                          South Africa   146
# 34                                               Morocco   140
# 35                                                Israel   138
# 36                                              Thailand   123
# 37                                              Portugal   119
# 38                                                  Peru   117
# 39                                  United Arab Emirates   111
# 40                                               Tunisia   109
# 41                                           Philippines   108
# 42                                             Sri Lanka   106
# 43                                                Greece   102
# 44                                                 Chile   102
# 45                                                 Ghana    99
# 46                                          Saudi Arabia    89
# 47                                               Ireland    84
# 48                                                Sweden    81
# 49                                    Hong Kong (S.A.R.)    79
# 50                                                 Nepal    75
# 51                                           Switzerland    71
# 52                 I do not wish to disclose my location    69
# 53                                               Belgium    65
# 54                                        Czech Republic    63
# 55                                               Romania    61
# 56                                               Austria    51
# 57                                               Belarus    51
# 58                                               Ecuador    50
# 59                                               Denmark    48
# 60                                                Uganda    47
# 61                                            Kazakhstan    45
# 62                                                Norway    45
# 63                                               Algeria    44
# 64                                              Ethiopia    43
# 65                                                  Iraq    43

# %% [markdown]
# ## Exploración por formación

# %%
df['formacion'].value_counts().reset_index()
# Out:
#                                                                index  \
# 0                                                    Master’s degree
# 1                                                  Bachelor’s degree
# 2                                                    Doctoral degree
# 3  Some college/university study without earning a bachelor’s degree
# 4                                             I prefer not to answer
# 5                               No formal education past high school
# 6                                             Professional doctorate
#
#    formacion
# 0      10132
# 1       9907
# 2       2795
# 3       1735
# 4        627
# 5        417
# 6        360

# %% [markdown]
# ## Exploración por ocupación

# %%
df['ocupacion'].value_counts().reset_index()
# Out:
#                            index  ocupacion
# 0                        Student       6804
# 1                 Data Scientist       3616
# 2              Software Engineer       2449
# 3                          Other       2393
# 4                   Data Analyst       2301
# 5         Currently not employed       1986
# 6             Research Scientist       1538
# 7      Machine Learning Engineer       1499
# 8               Business Analyst        968
# 9        Program/Project Manager        849
# 10                 Data Engineer        668
# 11               Product Manager        319
# 12                  Statistician        313
# 13         DBA/Database Engineer        171
# 14  Developer Relations/Advocacy         99

# %% [markdown]
# ## Exploración por actividades

# %%
df['actividades'].value_counts().reset_index()
# Out:
#                                                                                         index  \
# 0                      Analyze and understand data to influence product or business decisions
# 1                           None of these activities are an important part of my role at work
# 2   Analyze and understand data to influence product or business decisions, Build and/or r...
# 3   Analyze and understand data to influence product or business decisions, Build and/or r...
# 4                                                                                       Other
# 5    Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 6   Analyze and understand data to influence product or business decisions, Build prototyp...
# 7   Analyze and understand data to influence product or business decisions, Build and/or r...
# 8                          Do research that advances the state of the art of machine learning
# 9                          Build prototypes to explore applying machine learning to new areas
# 10  Analyze and understand data to influence product or business decisions, Build and/or r...
# 11  Analyze and understand data to influence product or business decisions, Build and/or r...
# 12  Analyze and understand data to influence product or business decisions, Build prototyp...
# 13  Analyze and understand data to influence product or business decisions, Build prototyp...
# 14   Build and/or run a machine learning service that operationally improves my product or...
# 15  Analyze and understand data to influence product or business decisions, Build prototyp...
# 16                                Experimentation and iteration to improve existing ML models
# 17  Analyze and understand data to influence product or business decisions, Do research th...
# 18  Analyze and understand data to influence product or business decisions, Build and/or r...
# 19  Analyze and understand data to influence product or business decisions, Experimentatio...
# 20   Build prototypes to explore applying machine learning to new areas, Experimentation a...
# 21  Analyze and understand data to influence product or business decisions, Build prototyp...
# 22  Analyze and understand data to influence product or business decisions, Build and/or r...
# 23  Analyze and understand data to influence product or business decisions, Build prototyp...
# 24   Experimentation and iteration to improve existing ML models, Do research that advance...
# 25  Analyze and understand data to influence product or business decisions, Build prototyp...
# 26  Analyze and understand data to influence product or business decisions, Build and/or r...
# 27   Build prototypes to explore applying machine learning to new areas, Build and/or run ...
# 28   Build prototypes to explore applying machine learning to new areas, Experimentation a...
# 29   Build prototypes to explore applying machine learning to new areas, Do research that ...
# 30  Analyze and understand data to influence product or business decisions, Experimentatio...
# 31   Build prototypes to explore applying machine learning to new areas, Build and/or run ...
# 32  Analyze and understand data to influence product or business decisions, Build and/or r...
# 33   Build prototypes to explore applying machine learning to new areas, Build and/or run ...
# 34  Analyze and understand data to influence product or business decisions, Build and/or r...
# 35  Analyze and understand data to influence product or business decisions, Build and/or r...
# 36   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 37  Analyze and understand data to influence product or business decisions, Build and/or r...
# 38  Analyze and understand data to influence product or business decisions, Build and/or r...
# 39  Analyze and understand data to influence product or business decisions, Build and/or r...
# 40   Build and/or run a machine learning service that operationally improves my product or...
# 41  Analyze and understand data to influence product or business decisions, Build and/or r...
# 42              Analyze and understand data to influence product or business decisions, Other
# 43  Analyze and understand data to influence product or business decisions, Build and/or r...
# 44  Analyze and understand data to influence product or business decisions, Build prototyp...
# 45   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 46  Analyze and understand data to influence product or business decisions, Build and/or r...
# 47   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 48   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 49  Analyze and understand data to influence product or business decisions, Build and/or r...
# 50  Analyze and understand data to influence product or business decisions, Build and/or r...
# 51   Build and/or run a machine learning service that operationally improves my product or...
# 52  Analyze and understand data to influence product or business decisions, Build and/or r...
# 53   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 54   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 55   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 56   Build and/or run a machine learning service that operationally improves my product or...
# 57   Build prototypes to explore applying machine learning to new areas, Build and/or run ...
# 58   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 59   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 60   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 61   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 62  Analyze and understand data to influence product or business decisions, Build and/or r...
# 63   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 64   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 65  Analyze and understand data to influence product or business decisions, Build and/or r...
# 66   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 67   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 68   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 69                  Build prototypes to explore applying machine learning to new areas, Other
# 70  Analyze and understand data to influence product or business decisions, Experimentatio...
# 71   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 72                         Experimentation and iteration to improve existing ML models, Other
# 73  Analyze and understand data to influence product or business decisions, Build and/or r...
# 74   Build prototypes to explore applying machine learning to new areas, Experimentation a...
# 75   Build prototypes to explore applying machine learning to new areas, Build and/or run ...
# 76  Analyze and understand data to influence product or business decisions, Build and/or r...
# 77   Build prototypes to explore applying machine learning to new areas, Experimentation a...
# 78   Build and/or run a machine learning service that operationally improves my product or...
# 79  Analyze and understand data to influence product or business decisions, Build prototyp...
# 80                  Do research that advances the state of the art of machine learning, Other
# 81  Analyze and understand data to influence product or business decisions, Build prototyp...
# 82  Analyze and understand data to influence product or business decisions, Build and/or r...
# 83  Analyze and understand data to influence product or business decisions, Build and/or r...
# 84   Build and/or run a machine learning service that operationally improves my product or...
# 85  Analyze and understand data to influence product or business decisions, Experimentatio...
# 86  Analyze and understand data to influence product or business decisions, Build prototyp...
# 87  Analyze and understand data to influence product or business decisions, Build prototyp...
# 88   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 89  Analyze and understand data to influence product or business decisions, Build and/or r...
# 90   Build prototypes to explore applying machine learning to new areas, Do research that ...
# 91  Analyze and understand data to influence product or business decisions, Build prototyp...
# 92  Analyze and understand data to influence product or business decisions, Build and/or r...
# 93   Build and/or run the data infrastructure that my business uses for storing, analyzing...
# 94  Analyze and understand data to influence product or business decisions, Do research th...
# 95  Analyze and understand data to influence product or business decisions, Build and/or r...
#
#     actividades
# 0          2891
# 1          2825
# 2          1026
# 3           686
# 4           543
# 5           457
# 6           433
# 7           402
# 8           395
# 9           391
# 10          380
# 11          264
# 12          257
# 13          254
# 14          243
# 15          204
# 16          197
# 17          196
# 18          193
# 19          182
# 20          164
# 21          163
# 22          152
# 23          150
# 24          141
# 25          134
# 26          128
# 27          120
# 28          115
# 29          111
# 30          108
# 31          100
# 32           98
# 33           93
# 34           88
# 35           86
# 36           86
# 37           81
# 38           66
# 39           60
# 40           60
# 41           57
# 42           53
# 43           50
# 44           50
# 45           50
# 46           48
# 47           45
# 48           44
# 49           44
# 50           43
# 51           39
# 52           34
# 53           33
# 54           31
# 55           30
# 56           28
# 57           27
# 58           23
# 59           22
# 60           20
# 61           18
# 62           16
# 63           13
# 64           12
# 65           11
# 66           10
# 67            9
# 68            7
# 69            5
# 70            3
# 71            3
# 72            3
# 73            3
# 74            3
# 75            2
# 76            2
# 77            2
# 78            2
# 79            1
# 80            1
# 81            1
# 82            1
# 83            1
# 84            1
# 85            1
# 86            1
# 87            1
# 88            1
# 89            1
# 90            1
# 91            1
# 92            1
# 93            1
# 94            1
# 95            1

# %% [markdown]
# ## Exploración por sector

# %%
df['sector'].value_counts().reset_index()
# Out:
#                                      index  sector
# 0                     Computers/Technology    4079
# 1                      Academics/Education    3214
# 2                       Accounting/Finance    1459
# 3                                    Other    1136
# 4                Manufacturing/Fabrication     872
# 5                   Medical/Pharmaceutical     776
# 6                Government/Public Service     726
# 7   Online Service/Internet-based Services     585
# 8                            Energy/Mining     558
# 9                             Retail/Sales     536
# 10               Insurance/Risk Assessment     424
# 11                           Marketing/CRM     373
# 12             Broadcasting/Communications     326
# 13                 Shipping/Transportation     316
# 14                      Non-profit/Service     300
# 15    Online Business/Internet-based Sales     275
# 16               Military/Security/Defense     197
# 17        Hospitality/Entertainment/Sports     173

# %% [markdown]
# ## Exploración por tamaño de la empresa

# %%
df['tamaño_empresa'].value_counts().reset_index()
# Out:
#                       index  tamaño_empresa
# 0            0-49 employees            5055
# 1  10,000 or more employees            3416
# 2      1000-9,999 employees            3059
# 3          50-249 employees            2567
# 4         250-999 employees            2154

# %% [markdown]
# ## Exploración por tamaño del equipo

# %%
df['equipo'].value_counts().reset_index()
# Out:
#    index  equipo
# 0    1-2    3642
# 1    20+    3595
# 2      0    3064
# 3    3-4    2558
# 4    5-9    1850
# 5  10-14     996
# 6  15-19     421

# %% [markdown]
# ## Exploración por salario

# %%
df['salario'].value_counts().reset_index().sort_values(by="index")
# Out:
#                index  salario
# 0             $0-999     3369
# 25  $500,000-999,999       32
# 1        1,000-1,999      969
# 2      10,000-14,999      950
# 4    100,000-124,999      725
# 19   125,000-149,999      379
# 10     15,000-19,999      573
# 16   150,000-199,999      392
# 9        2,000-2,999      575
# 8      20,000-24,999      587
# 21   200,000-249,999      177
# 13     25,000-29,999      470
# 23   250,000-299,999       75
# 18       3,000-3,999      380
# 3      30,000-39,999      741
# 22   300,000-499,999       91
# 15       4,000-4,999      456
# 7      40,000-49,999      688
# 5        5,000-7,499      699
# 6      50,000-59,999      697
# 12     60,000-69,999      551
# 11       7,500-9,999      552
# 14     70,000-79,999      464
# 17     80,000-89,999      391
# 20     90,000-99,999      350
# 24       >$1,000,000       58

# %%
df['productos_big_data'].unique()
# Out:
# array([nan, 'MySQL ', 'IBM Db2 ', 'PostgreSQL ',
#        'Google Cloud Firestore ', 'Oracle Database ',
#        'Microsoft SQL Server ', 'Microsoft Azure SQL Database ',
#        'Snowflake ', 'MongoDB ', 'Google Cloud BigQuery ',
#        'Amazon DynamoDB ', 'SQLite ', 'Amazon RDS ', 'Amazon Redshift ',
#        'Google Cloud BigTable ', 'Google Cloud SQL ',
#        'Microsoft Azure Cosmos DB ', 'Other', 'Amazon Aurora ',
#        'Google Cloud Spanner '], dtype=object)

# %%
df['productos_big_data'].value_counts()
# Out:
# MySQL                            1110
# PostgreSQL                        694
# Microsoft SQL Server              611
# MongoDB                           342
# Oracle Database                   316
# Google Cloud BigQuery             298
# SQLite                            235
# Microsoft Azure SQL Database      191
# Amazon Redshift                   146
# Snowflake                         132
# Amazon RDS                         94
# Google Cloud SQL                   79
# IBM Db2                            78
# Amazon DynamoDB                    77
# Other                              64
# Google Cloud Firestore             60
# Microsoft Azure Cosmos DB          54
# Amazon Aurora                      34
# Google Cloud BigTable              31
# Google Cloud Spanner               10
# Name: productos_big_data, dtype: int64

# %% [markdown]
#  ## Analistas Datos en todo el DF

# %%
df_data_analyst = df[df['ocupacion'] == 'Data Analyst']
df_data_analyst.sample()
# Out:
#        edad genero   pais          formacion     ocupacion  \
# 5561  22-24    Man  India  Bachelor’s degree  Data Analyst
#
#      lenguajes_programacion lenguajes_recomendados  \
# 5561            Python, SQL                      R
#
#                                                 IDE plataforma_computacion  \
# 5561  Visual Studio Code (VSCode) ,Jupyter Notebook               A laptop
#
#                               visualizacion                     sector  \
# 5561   Matplotlib ,Plotly / Plotly Express   Insurance/Risk Assessment
#
#                 tamaño_empresa equipo  \
# 5561  10,000 or more employees  15-19
#
#                                                               actividades  \
# 5561   Do research that advances the state of the art of machine learning
#
#           salario     productos_big_data  \
# 5561  3,000-3,999  Microsoft SQL Server
#
#                                       herramienta_data_analytics  \
# 5561  Local development environments (RStudio, JupyterLab, etc.)
#
#             notebooks   plataformas_nube                     uso_plataformas  \
# 5561  Colab Notebooks   Microsoft Azure    Microsoft Azure Virtual Machines
#
#                                          formacion_data  \
# 5561  LinkedIn Learning, Coursera, Kaggle Learn Courses
#
#                        fuentes_online
# 5561  Kaggle (notebooks, forums, etc)

# %% [markdown]
# ## EUROPA

# %%
lista_europeos = ['Russia', 'United Kingdom of Great Britain and Northern Ireland', 'Germany', 'Spain', 'Turkey', 'France', 'Italy', 'Poland', 'Ukraine', 'Portugal', 'Greece', 'Ireland', 'Sweden', 'Switzerland', 'Belgium', 'Czech Republic', 'Romania', 'Austria', 'Belarus', 'Denmark', 'Norway']

# %%
df_europa = df[df['pais'].isin(lista_europeos)]
df_europa.sample()
# Out:
#         edad genero    pais        formacion                  ocupacion  \
# 12975  25-29    Man  France  Master’s degree  Machine Learning Engineer
#
#                                                                                      actividades  \
# 12975  Analyze and understand data to influence product or business decisions, Build and/or r...
#
#                           sector            tamaño_empresa equipo  \
# 12975  Manufacturing/Fabrication  10,000 or more employees    5-9
#
#              salario         lenguajes_programacion lenguajes_recomendados  \
# 12975  80,000-89,999  Python, SQL, Javascript, Bash                 Python
#
#                                                                                              IDE  \
# 12975  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) ,PyCharm ,Ju...
#
#                                                     plataforma_computacion  \
# 12975  A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc)
#
#                                                           visualizacion  \
# 12975   Matplotlib ,Seaborn ,Plotly / Plotly Express ,Leaflet / Folium
#
#            productos_big_data  \
# 12975  Google Cloud BigQuery
#
#                                        herramienta_data_analytics  \
# 12975  Local development environments (RStudio, JupyterLab, etc.)
#
#                                                notebooks  \
# 12975  Google Cloud Notebooks (AI Platform / Vertex AI)
#
#                     plataformas_nube                uso_plataformas
# 12975   Google Cloud Platform (GCP)    Google Cloud Compute Engine

# %%
df_europa.describe(include='all').T
# Out:
#                            count unique  \
# edad                        4590     11
# genero                      4590      5
# pais                        4590     21
# formacion                   4590      7
# ocupacion                   4590     15
# actividades                 3262     78
# sector                      3388     18
# tamaño_empresa              3377      5
# equipo                      3359      7
# salario                     3209     26
# lenguajes_programacion      4477    442
# lenguajes_recomendados      4477     13
# IDE                         4477    674
# plataforma_computacion      4451      6
# visualizacion               4360    247
# productos_big_data           999     20
# herramienta_data_analytics  3546      6
# notebooks                   4462    238
# plataformas_nube            2024     97
# uso_plataformas             1229     14
#
#                                                                                            top  \
# edad                                                                                     25-29
# genero                                                                                     Man
# pais                                                                                    Russia
# formacion                                                                      Master’s degree
# ocupacion                                                                       Data Scientist
# actividades                  None of these activities are an important part of my role at work
# sector                                                                    Computers/Technology
# tamaño_empresa                                                                  0-49 employees
# equipo                                                                                     1-2
# salario                                                                                 $0-999
# lenguajes_programacion                                                                  Python
# lenguajes_recomendados                                                                  Python
# IDE                                                                           Jupyter Notebook
# plataforma_computacion                                                                A laptop
# visualizacion                                                             Matplotlib ,Seaborn
# productos_big_data                                                                      MySQL
# herramienta_data_analytics          Local development environments (RStudio, JupyterLab, etc.)
# notebooks                                                                                 None
# plataformas_nube                                                                          None
# uso_plataformas                                                                      No / None
#
#                             freq
# edad                         883
# genero                      3779
# pais                         742
# formacion                   2287
# ocupacion                    848
# actividades                  621
# sector                       664
# tamaño_empresa               974
# equipo                       786
# salario                      389
# lenguajes_programacion       877
# lenguajes_recomendados      3636
# IDE                          309
# plataforma_computacion      2517
# visualizacion               1027
# productos_big_data           198
# herramienta_data_analytics  1731
# notebooks                   1512
# plataformas_nube             669
# uso_plataformas              400

# %%
(df_europa["genero"].value_counts()*100/df_europa.shape[0]).round(2)
# Out:
# Man                        82.33
# Woman                      15.97
# Prefer not to say           1.15
# Nonbinary                   0.31
# Prefer to self-describe     0.24
# Name: genero, dtype: float64

# %% [markdown]
# - Filtrado por Data Analyst

# %%
data_europa = df_europa[df_europa['ocupacion']== 'Data Analyst']
data_europa.describe(include= 'all').T
# Out:
#                            count unique  \
# edad                         290     10
# genero                       290      5
# pais                         290     20
# formacion                    290      7
# ocupacion                    290      1
# actividades                  264     39
# sector                       278     18
# tamaño_empresa               277      5
# equipo                       273      7
# salario                      258     21
# lenguajes_programacion       279     60
# lenguajes_recomendados       279      9
# IDE                          279    124
# plataforma_computacion       278      6
# visualizacion                274     72
# productos_big_data            68     11
# herramienta_data_analytics   231      6
# notebooks                    278     45
# plataformas_nube             148     28
# uso_plataformas               75      7
#
#                                                                                                top  \
# edad                                                                                         25-29
# genero                                                                                         Man
# pais                                          United Kingdom of Great Britain and Northern Ireland
# formacion                                                                          Master’s degree
# ocupacion                                                                             Data Analyst
# actividades                 Analyze and understand data to influence product or business decisions
# sector                                                                          Accounting/Finance
# tamaño_empresa                                                                      0-49 employees
# equipo                                                                                         1-2
# salario                                                                                     $0-999
# lenguajes_programacion                                                                 Python, SQL
# lenguajes_recomendados                                                                      Python
# IDE                                                                               Jupyter Notebook
# plataforma_computacion                                                                    A laptop
# visualizacion                                                                 Matplotlib ,Seaborn
# productos_big_data                                                                          MySQL
# herramienta_data_analytics              Local development environments (RStudio, JupyterLab, etc.)
# notebooks                                                                                     None
# plataformas_nube                                                                              None
# uso_plataformas                                                                          No / None
#
#                            freq
# edad                         65
# genero                      220
# pais                         53
# formacion                   171
# ocupacion                   290
# actividades                  80
# sector                       39
# tamaño_empresa               74
# equipo                       72
# salario                      35
# lenguajes_programacion       69
# lenguajes_recomendados      211
# IDE                          27
# plataforma_computacion      189
# visualizacion                48
# productos_big_data           23
# herramienta_data_analytics   79
# notebooks                   113
# plataformas_nube             59
# uso_plataformas              40

# %%
(data_europa['genero'].value_counts()*100/data_europa.shape[0]).round(2)
# Out:
# Man                        75.86
# Woman                      22.41
# Prefer not to say           1.03
# Prefer to self-describe     0.34
# Nonbinary                   0.34
# Name: genero, dtype: float64

# %%
# Out:
#                            count unique  \
# edad                         358     10
# genero                       358      5
# pais                         358     21
# formacion                    358      7
# ocupacion                    358      1
# actividades                  326     42
# sector                       344     18
# tamaño_empresa               343      5
# equipo                       339      7
# salario                      318     22
# lenguajes_programacion       346     68
# lenguajes_recomendados       346      9
# IDE                          346    142
# plataforma_computacion       345      6
# visualizacion                340     79
# productos_big_data            92     12
# herramienta_data_analytics   285      6
# notebooks                    345     55
# plataformas_nube             182     32
# uso_plataformas               90      8
#
#                                                                                                top  \
# edad                                                                                         25-29
# genero                                                                                         Man
# pais                                                                                        Russia
# formacion                                                                          Master’s degree
# ocupacion                                                                             Data Analyst
# actividades                 Analyze and understand data to influence product or business decisions
# sector                                                                          Accounting/Finance
# tamaño_empresa                                                                      0-49 employees
# equipo                                                                                         1-2
# salario                                                                                     $0-999
# lenguajes_programacion                                                                 Python, SQL
# lenguajes_recomendados                                                                      Python
# IDE                                                                               Jupyter Notebook
# plataforma_computacion                                                                    A laptop
# visualizacion                                                                 Matplotlib ,Seaborn
# productos_big_data                                                                          MySQL
# herramienta_data_analytics              Local development environments (RStudio, JupyterLab, etc.)
# notebooks                                                                                     None
# plataformas_nube                                                                              None
# uso_plataformas                                                                          No / None
#
#                            freq
# edad                         81
# genero                      276
# pais                         68
# formacion                   204
# ocupacion                   358
# actividades                 104
# sector                       52
# tamaño_empresa               89
# equipo                       90
# salario                      42
# lenguajes_programacion       93
# lenguajes_recomendados      268
# IDE                          34
# plataforma_computacion      225
# visualizacion                63
# productos_big_data           29
# herramienta_data_analytics  104
# notebooks                   127
# plataformas_nube             72
# uso_plataformas              48

# %% [markdown]
# ## INDIA

# %%
df_indo = df[df['Q3'] == 'India']
df_indo.sample()
# Out:
#        age gender     Q3               Q4       Q5         Q7      Q8  \
# 503  25-29    Man  India  Master’s degree  Student  Python, R  Python
#
#                                     Q9       Q11  \
# 503  RStudio ,MATLAB ,Jupyter Notebook  A laptop
#
#                                                                   Q14  Q20  \
# 503   Matplotlib ,Seaborn ,Plotly / Plotly Express ,Ggplot / ggplot2   NaN
#
#      Q21  Q22  Q24  Q25  Q32  Q33  \
# 503  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                                             Q41  \
# 503  Local development environments (RStudio, JupyterLab, etc.)
#
#        q_10_completa q_27_completa q_29_completa  \
# 503  Colab Notebooks           NaN           NaN
#
#                                                                                  q_40_completa  \
# 503  Coursera, Kaggle Learn Courses, Cloud-certification programs (direct from AWS, Azure, ...
#
#                                                                                  q_42_completa
# 503  Kaggle (notebooks, forums, etc), Podcasts (Chai Time Data Science, O’Reilly Data Show,...

# %%
df_indo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7434 entries, 0 to 25972
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            7434 non-null   object
#  1   gender         7434 non-null   object
#  2   Q3             7434 non-null   object
#  3   Q4             7434 non-null   object
#  4   Q5             7434 non-null   object
#  5   Q7             7151 non-null   object
#  6   Q8             7151 non-null   object
#  7   Q9             7148 non-null   object
#  8   Q11            7072 non-null   object
#  9   Q14            6743 non-null   object
#  10  Q20            3681 non-null   object
#  11  Q21            3645 non-null   object
#  12  Q22            3599 non-null   object
#  13  Q24            3447 non-null   object
#  14  Q25            3376 non-null   object
#  15  Q32            1967 non-null   object
#  16  Q33            1020 non-null   object
#  17  Q41            4606 non-null   object
#  18  q_10_completa  7099 non-null   object
#  19  q_27_completa  2034 non-null   object
#  20  q_29_completa  1393 non-null   object
#  21  q_40_completa  4838 non-null   object
#  22  q_42_completa  4555 non-null   object
# dtypes: object(23)
# memory usage: 1.4+ MB

# %%
df_indo.describe(include='all').T
# Out:
#               count unique  \
# age            7434     11
# gender         7434      5
# Q3             7434      1
# Q4             7434      7
# Q5             7434     15
# Q7             7151    417
# Q8             7151     13
# Q9             7148    763
# Q11            7072      6
# Q14            6743    246
# Q20            3681     18
# Q21            3645      5
# Q22            3599      7
# Q24            3447     78
# Q25            3376     26
# Q32            1967    544
# Q33            1020     20
# Q41            4606      6
# q_10_completa  7099    377
# q_27_completa  2034    147
# q_29_completa  1393     12
# q_40_completa  4838    546
# q_42_completa  4555    509
#
#                                                                                                      top  \
# age                                                                                                18-21
# gender                                                                                               Man
# Q3                                                                                                 India
# Q4                                                                                     Bachelor’s degree
# Q5                                                                                               Student
# Q7                                                                                                Python
# Q8                                                                                                Python
# Q9                                                                                      Jupyter Notebook
# Q11                                                                                             A laptop
# Q14                                                                                 Matplotlib ,Seaborn
# Q20                                                                                 Computers/Technology
# Q21                                                                             10,000 or more employees
# Q22                                                                                                  20+
# Q24                               Analyze and understand data to influence product or business decisions
# Q25                                                                                               $0-999
# Q32                                                                                                 None
# Q33                                                                                               MySQL
# Q41                                    Basic statistical software (Microsoft Excel, Google Sheets, etc.)
# q_10_completa                                                                                       None
# q_27_completa                                                                                       None
# q_29_completa                                                                                  No / None
# q_40_completa                                                                                       None
# q_42_completa  Kaggle (notebooks, forums, etc), YouTube (Kaggle YouTube, Cloud AI Adventures, etc), B...
#
#                freq
# age            2719
# gender         5681
# Q3             7434
# Q4             4008
# Q5             2845
# Q7             1296
# Q8             6019
# Q9              858
# Q11            5417
# Q14            1918
# Q20            1317
# Q21            1157
# Q22             958
# Q24             641
# Q25             978
# Q32             430
# Q33             280
# Q41            2140
# q_10_completa  1530
# q_27_completa   499
# q_29_completa   376
# q_40_completa   328
# q_42_completa   392

# %% [markdown]
# - Filtrado por Data Analyst

# %%
data_indo = df_indo[df_indo['Q5']== 'Data Analyst']
data_indo.describe(include= 'all').T
# Out:
#               count unique  \
# age             564      9
# gender          564      5
# Q3              564      1
# Q4              564      7
# Q5              564      1
# Q7              516    103
# Q8              516      9
# Q9              514    161
# Q11             513      6
# Q14             498     79
# Q20             527     18
# Q21             520      5
# Q22             516      7
# Q24             489     56
# Q25             479     21
# Q32             277    114
# Q33             138     18
# Q41             391      6
# q_10_completa   513     91
# q_27_completa   291     58
# q_29_completa   179     10
# q_40_completa   403    137
# q_42_completa   388    122
#
#                                                                                   top  \
# age                                                                             22-24
# gender                                                                            Man
# Q3                                                                              India
# Q4                                                                  Bachelor’s degree
# Q5                                                                       Data Analyst
# Q7                                                                        Python, SQL
# Q8                                                                             Python
# Q9                                                                   Jupyter Notebook
# Q11                                                                          A laptop
# Q14                                                              Matplotlib ,Seaborn
# Q20                                                              Computers/Technology
# Q21                                                          10,000 or more employees
# Q22                                                                               20+
# Q24            Analyze and understand data to influence product or business decisions
# Q25                                                                            $0-999
# Q32                                                                              None
# Q33                                                                            MySQL
# Q41                 Basic statistical software (Microsoft Excel, Google Sheets, etc.)
# q_10_completa                                                                    None
# q_27_completa                                                                    None
# q_29_completa                                                               No / None
# q_40_completa                                                                   Other
# q_42_completa                                         Kaggle (notebooks, forums, etc)
#
#               freq
# age            164
# gender         420
# Q3             564
# Q4             271
# Q5             564
# Q7             120
# Q8             407
# Q9              91
# Q11            396
# Q14            137
# Q20            149
# Q21            158
# Q22            131
# Q24            167
# Q25            153
# Q32             56
# Q33             37
# Q41            190
# q_10_completa  106
# q_27_completa   90
# q_29_completa   58
# q_40_completa   29
# q_42_completa   46

# %%
data_indo['gender'].value_counts()
# Out:
# Man                        420
# Woman                      137
# Prefer not to say            4
# Prefer to self-describe      2
# Nonbinary                    1
# Name: gender, dtype: int64

# %% [markdown]
# ## USA

# %%
df_usa = df[df['Q3'] == 'United States of America']
df_usa.sample()
# Out:
#        age gender                        Q3               Q4     Q5      Q7  \
# 104  40-44  Woman  United States of America  Master’s degree  Other  Python
#
#          Q8  \
# 104  Python
#
#                                                                                             Q9  \
# 104  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio Code (VSCode) , Vim / Emac...
#
#           Q11                    Q14                  Q20               Q21  \
# 104  A laptop   Matplotlib ,Seaborn   Academics/Education  50-249 employees
#
#      Q22  \
# 104  5-9
#
#                                                                                            Q24  \
# 104  Analyze and understand data to influence product or business decisions, Build and/or r...
#
#                Q25    Q32  Q33  \
# 104  25,000-29,999   None  NaN
#
#                                                             Q41  \
# 104  Local development environments (RStudio, JupyterLab, etc.)
#
#                           q_10_completa  \
# 104   Kaggle Notebooks, Colab Notebooks
#
#                                                   q_27_completa  \
# 104   Amazon Web Services (AWS) ,  Google Cloud Platform (GCP)
#
#                      q_29_completa  \
# 104   Google Cloud Compute Engine
#
#                                                                                  q_40_completa  \
# 104  Udacity, Kaggle Learn Courses, Coursera, University Courses (resulting in a university...
#
#                                                                                  q_42_completa
# 104  Kaggle (notebooks, forums, etc), YouTube (Kaggle YouTube, Cloud AI Adventures, etc), T...

# %%
df_usa.describe(include= 'all').T
# Out:
#               count unique  \
# age            2650     11
# gender         2650      5
# Q3             2650      1
# Q4             2650      7
# Q5             2650     15
# Q7             2528    363
# Q8             2527     13
# Q9             2527    556
# Q11            2510      6
# Q14            2471    212
# Q20            1924     18
# Q21            1921      5
# Q22            1911      7
# Q24            1867     74
# Q25            1845     26
# Q32            1276    395
# Q33             624     20
# Q41            2058      6
# q_10_completa  2517    191
# q_27_completa  1306     80
# q_29_completa   916     12
# q_40_completa  2110    437
# q_42_completa  2042    465
#
#                                                                                   top  \
# age                                                                             30-34
# gender                                                                            Man
# Q3                                                           United States of America
# Q4                                                                    Master’s degree
# Q5                                                                            Student
# Q7                                                                             Python
# Q8                                                                             Python
# Q9                                                                   Jupyter Notebook
# Q11                                                                          A laptop
# Q14                                                                              None
# Q20                                                              Computers/Technology
# Q21                                                          10,000 or more employees
# Q22                                                                               20+
# Q24            Analyze and understand data to influence product or business decisions
# Q25                                                                   100,000-124,999
# Q32                                                                              None
# Q33                                                             Microsoft SQL Server
# Q41                        Local development environments (RStudio, JupyterLab, etc.)
# q_10_completa                                                                    None
# q_27_completa                                                                    None
# q_29_completa                                     Amazon Elastic Compute Cloud (EC2)
# q_40_completa                                                                    None
# q_42_completa                                                                    None
#
#                freq
# age             407
# gender         1949
# Q3             2650
# Q4             1235
# Q5              452
# Q7              322
# Q8             1897
# Q9              157
# Q11            1451
# Q14             415
# Q20             419
# Q21             628
# Q22             673
# Q24             312
# Q25             289
# Q32             298
# Q33             116
# Q41             880
# q_10_completa  1042
# q_27_completa   306
# q_29_completa   279
# q_40_completa   163
# q_42_completa   151

# %% [markdown]
# - Filtrado por Data Analyst

# %%
data_usa = df_usa[df_usa['Q5']== 'Data Analyst']
data_usa.describe(include= 'all').T
# Out:
#               count unique  \
# age             258     11
# gender          258      4
# Q3              258      1
# Q4              258      7
# Q5              258      1
# Q7              243     53
# Q8              242     10
# Q9              242    115
# Q11             241      6
# Q14             235     68
# Q20             243     17
# Q21             242      5
# Q22             241      7
# Q24             233     37
# Q25             227     23
# Q32             154     69
# Q33              75     14
# Q41             201      6
# q_10_completa   241     42
# q_27_completa   156     29
# q_29_completa    97      9
# q_40_completa   207    122
# q_42_completa   199    100
#
#                                                                                   top  \
# age                                                                             30-34
# gender                                                                            Man
# Q3                                                           United States of America
# Q4                                                                    Master’s degree
# Q5                                                                       Data Analyst
# Q7                                                                        Python, SQL
# Q8                                                                             Python
# Q9                                                                   Jupyter Notebook
# Q11                                                                          A laptop
# Q14                                                                              None
# Q20                                                               Academics/Education
# Q21                                                          10,000 or more employees
# Q22                                                                               20+
# Q24            Analyze and understand data to influence product or business decisions
# Q25                                                                   100,000-124,999
# Q32                                                                              None
# Q33                                                             Microsoft SQL Server
# Q41                        Local development environments (RStudio, JupyterLab, etc.)
# q_10_completa                                                                    None
# q_27_completa                                                                    None
# q_29_completa                                                               No / None
# q_40_completa                                                                Coursera
# q_42_completa                                                                    None
#
#               freq
# age             52
# gender         171
# Q3             258
# Q4             143
# Q5             258
# Q7              48
# Q8             146
# Q9              21
# Q11            164
# Q14             36
# Q20             34
# Q21             71
# Q22             67
# Q24             69
# Q25             42
# Q32             29
# Q33             26
# Q41             70
# q_10_completa  102
# q_27_completa   49
# q_29_completa   48
# q_40_completa   15
# q_42_completa   21

# %%
data_usa['gender'].value_counts()
# Out:
# Man                  171
# Woman                 77
# Prefer not to say      8
# Nonbinary              2
# Name: gender, dtype: int64

# %% [markdown]
# ## ESPAÑA

# %%
df_spain = df[df['Q3'] == 'Spain']
df_spain.sample()
# Out:
#          age gender     Q3               Q4              Q5         Q7  \
# 18132  25-29    Man  Spain  Master’s degree  Data Scientist  Python, R
#
#            Q8  \
# 18132  Python
#
#                                                                     Q9  \
# 18132  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,RStudio ,PyCharm
#
#             Q11                                      Q14                 Q20  \
# 18132  A laptop   Matplotlib ,Seaborn ,Ggplot / ggplot2   Accounting/Finance
#
#                             Q21  Q22  \
# 18132  10,000 or more employees  20+
#
#                                                                                              Q24  \
# 18132  Analyze and understand data to influence product or business decisions, Build and/or r...
#
#                  Q25                            Q32               Q33  \
# 18132  50,000-59,999   Oracle Database , Snowflake   Oracle Database
#
#                                                               Q41  \
# 18132  Local development environments (RStudio, JupyterLab, etc.)
#
#          q_10_completa      q_27_completa q_29_completa  \
# 18132  Colab Notebooks   Microsoft Azure      No / None
#
#                         q_40_completa                    q_42_completa
# 18132  Kaggle Learn Courses, DataCamp  Kaggle (notebooks, forums, etc)

# %%
df_spain.describe(include='all').T
# Out:
#               count unique  \
# age             454     11
# gender          454      4
# Q3              454      1
# Q4              454      7
# Q5              454     15
# Q7              442    145
# Q8              442     10
# Q9              442    191
# Q11             439      6
# Q14             435     95
# Q20             360     18
# Q21             360      5
# Q22             360      7
# Q24             347     51
# Q25             341     22
# Q32             206    108
# Q33             114     17
# Q41             362      6
# q_10_completa   440     66
# q_27_completa   211     32
# q_29_completa   132      9
# q_40_completa   372    165
# q_42_completa   358    148
#
#                                                                               top  \
# age                                                                         45-49
# gender                                                                        Man
# Q3                                                                          Spain
# Q4                                                                Master’s degree
# Q5                                                                 Data Scientist
# Q7                                                                         Python
# Q8                                                                         Python
# Q9                                  Visual Studio Code (VSCode) ,Jupyter Notebook
# Q11                                                                      A laptop
# Q14                                                          Matplotlib ,Seaborn
# Q20                                                           Academics/Education
# Q21                                                                0-49 employees
# Q22                                                                           1-2
# Q24             None of these activities are an important part of my role at work
# Q25                                                                 40,000-49,999
# Q32                                                                          None
# Q33                                                                        MySQL
# Q41                    Local development environments (RStudio, JupyterLab, etc.)
# q_10_completa                                                                None
# q_27_completa                                                                None
# q_29_completa                                                           No / None
# q_40_completa                                                                None
# q_42_completa                                     Kaggle (notebooks, forums, etc)
#
#               freq
# age             78
# gender         389
# Q3             454
# Q4             217
# Q5              70
# Q7              59
# Q8             345
# Q9              24
# Q11            242
# Q14             89
# Q20             80
# Q21             91
# Q22             87
# Q24             86
# Q25             52
# Q32             48
# Q33             28
# Q41            182
# q_10_completa  166
# q_27_completa   67
# q_29_completa   48
# q_40_completa   24
# q_42_completa   23

# %% [markdown]
# - Filtrado por Data Analyst

# %%
data_spain = df_spain[df_spain['Q5']== 'Data Analyst']
data_spain.describe(include= 'all').T
# Out:
#               count unique  \
# age              28      8
# gender           28      2
# Q3               28      1
# Q4               28      5
# Q5               28      1
# Q7               28     21
# Q8               28      6
# Q9               28     21
# Q11              28      4
# Q14              28     18
# Q20              27     10
# Q21              27      5
# Q22              27      6
# Q24              25     13
# Q25              24     12
# Q32              18     15
# Q33               9      6
# Q41              21      5
# q_10_completa    28     10
# q_27_completa    18     11
# q_29_completa    10      4
# q_40_completa    21     19
# q_42_completa    21     16
#
#                                                                                                      top  \
# age                                                                                                45-49
# gender                                                                                               Man
# Q3                                                                                                 Spain
# Q4                                                                                       Master’s degree
# Q5                                                                                          Data Analyst
# Q7                                                                                           Python, SQL
# Q8                                                                                                Python
# Q9                                                                                      Jupyter Notebook
# Q11                                                                                             A laptop
# Q14                                                                                 Matplotlib ,Seaborn
# Q20                                                                                  Academics/Education
# Q21                                                                                 1000-9,999 employees
# Q22                                                                                                  5-9
# Q24                               Analyze and understand data to influence product or business decisions
# Q25                                                                                        40,000-49,999
# Q32                                                                                               MySQL
# Q33                                                                                Microsoft SQL Server
# Q41                                           Local development environments (RStudio, JupyterLab, etc.)
# q_10_completa                                                                                       None
# q_27_completa                                                                                       None
# q_29_completa                                                                                  No / None
# q_40_completa                                      University Courses (resulting in a university degree)
# q_42_completa  Email newsletters (Data Elixir, O'Reilly Data & AI, etc), Blogs (Towards Data Science,...
#
#               freq
# age              7
# gender          21
# Q3              28
# Q4              13
# Q5              28
# Q7               4
# Q8              18
# Q9               4
# Q11             18
# Q14              5
# Q20              9
# Q21              8
# Q22              8
# Q24              6
# Q25              5
# Q32              3
# Q33              2
# Q41              9
# q_10_completa   16
# q_27_completa    6
# q_29_completa    5
# q_40_completa    2
# q_42_completa    3

# %%
data_spain['gender'].value_counts()
# Out:
# Man      21
# Woman     7
# Name: gender, dtype: int64

# %% [markdown]
# - Filtrados por Data Analyst hechos:
#
# -DF data_analyst Total
#
#  -España
#
#  -Europa
#
#  -India
#
#  -Estados Unidos

# %%
df_data_analyst.to_csv('data/encuesta_analistas.csv')
